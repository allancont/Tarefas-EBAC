# %% [markdown]
# # Módulo 10 atividade 1

# %% [markdown]
# Uma instituição financeira quer conhecer melhor o perfil de renda de seus novos clientes para diversos fins, por exemplo, melhor dimensionar o limite de cartões de crédito dos novos clientes, sem necessariamente solicitar olerites ou documentações que impactem na experiência do seu cliente.
#
# Para isto, conduziu um estudo com alguns clientes, comprovando suas rendas através de olerites e outros documentos, e pretende construir um modelo preditivo para esta renda com base em algumas variáveis que já possui em seu banco de dados.
#
# As variáveis são intuitivas - note que há uma variável 'index' que é um identificador do cliente e que em geral o ```read_csv``` do pandas coloca também uma variável sequencial.
#
# Estes dados estão no arquivo ```previsao_de_renda.csv```. Carregue-o em um *dataframe*.
#
# 1) Avalie a estrutura de correlação das variáveis quantitativas através de um gráfico de "matriz de dispersão" e através da avaliação gráfica da matriz de correlações. Veja se você identifica algum padrão interessante ou que te faça sentido.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Profissão- Cientista de Dados_M10_support material.csv', sep=',')

# %%
df.select_dtypes(include='number').head()
# Out:
#    Unnamed: 0  index  qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia  \
# 0           0   8682           1     36       3.575342                    3.0
# 1           1  12830           0     42       0.860274                    2.0
# 2           2   2885           2     31       8.065753                    4.0
# 3           3  16168           0     50       1.208219                    2.0
# 4           4  12438           0     52      13.873973                    2.0
#
#      renda
# 0  3369.24
# 1  6096.14
# 2  5658.98
# 3  7246.69
# 4  4017.37

# %%
#sns.pairplot(data=df)
df1=df[['tipo_renda','renda','qtd_filhos','idade','tempo_emprego','qt_pessoas_residencia']]
df1.corr()
# Out:
#                           renda  qtd_filhos     idade  tempo_emprego  \
# renda                  1.000000    0.009567  0.042570       0.394235
# qtd_filhos             0.009567    1.000000 -0.364303      -0.074250
# idade                  0.042570   -0.364303  1.000000       0.323934
# tempo_emprego          0.394235   -0.074250  0.323934       1.000000
# qt_pessoas_residencia  0.020977    0.896488 -0.338805      -0.065748
#
#                        qt_pessoas_residencia
# renda                               0.020977
# qtd_filhos                          0.896488
# idade                              -0.338805
# tempo_emprego                      -0.065748
# qt_pessoas_residencia               1.000000

# %%
sns.pairplot(df1, hue='tipo_renda')

# %%
renda_cmap = sns.diverging_palette(h_neg=125,h_pos=350,as_cmap=True,sep=60,center='light')
sns.clustermap(df1.corr(),figsize=(10,10),center=0,annot=True,cmap=renda_cmap)

# %%
_ = sns.heatmap(df1.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')

# %% [markdown]
# ### CONCLUSÃO
# A matriz de correlação (clustermap ou heatmap) demonstra que "tempo_emprego" é a variável que mais se relaciona com a "renda" 0.39.
# As demais variáveis, tais como "qtd_filhos", "idade" e "qt_pessoas_residencia" apresentaram valores muito próximos de zero, evidenciando uma baixa correlação com a "renda". ![heatmap2.jpg](attachment:heatmap2.jpg)

# %% [markdown]
# 3) Na sua opinião, há outliers na variável renda?

# %%
df1.boxplot(['renda'])
plt.title('Outliers')
df1.hist(['renda'])
plt.title('Renda com Outliers')
# Out:
# Text(0.5, 1.0, 'Renda com Outliers')

# %% [markdown]
# #### REMOVENDO OUTLIERS

# %%
valor = df1['renda']
Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor>= limite_inferior) & (valor <= limite_superior)
df1_new = df1[selecao]
df1_new.boxplot(['renda'])
plt.title('Outliers')
df1_new.hist(['renda'])
plt.title('Renda sem Outliers')
# Out:
# Text(0.5, 1.0, 'Renda sem Outliers')

# %%
_ = sns.regplot(x='tempo_emprego', y='renda', data = df1)
plt.title('Com Outliers')
# Out:
# Text(0.5, 1.0, 'Com Outliers')

# %%
_ = sns.regplot(x='tempo_emprego', y='renda', data = df1_new)
plt.title('Sem Outliers')
# Out:
# Text(0.5, 1.0, 'Sem Outliers')

# %% [markdown]
# ### CONCLUSÃO
# Conforme demonstrado anteriomente, resta confirmada a existência de outliers. No entanto ainda seria prematuro afirmar se tais ocorrências se tratem realmente de erro, uma vez que os padrões de renda, embora distantes da média, podem vir a ser perfeitamente plausíveis.![outiliers2.jpg](attachment:outiliers2.jpg)

# %% [markdown]
# 2) Avalie um gráfico de dispersão (*scatterplot*) específico para as duas variáveis mais correlacionadas com *renda*.

# %%
sns.regplot(x='idade', y='renda', data = df1_new)
plt.title('Renda x Idade')
# Out:
# Text(0.5, 1.0, 'Renda x Idade')

# %%
sns.regplot(x='tempo_emprego', y='renda', data = df1_new)
plt.title('Renda x Tempo Emprego')
# Out:
# Text(0.5, 1.0, 'Renda x Tempo Emprego')

# %% [markdown]
# 4) Calcule o logaritmo da variável renda e repita a sequência de análise

# %%
df4_log=df1[['tempo_emprego','renda']].copy()
df4_log.rename(columns={'tempo_emprego': 'x','renda': 'y'}, inplace=True)
df4_log['log_y'] = np.log(df4_log['y'])
df4_log.corr()
# Out:
#               x         y     log_y
# x      1.000000  0.394235  0.379556
# y      0.394235  1.000000  0.835734
# log_y  0.379556  0.835734  1.000000

# %%
# %matplotlib inline

sns.lmplot(x='x',
                  y='log_y', 
                 data=df4_log, 
                 scatter_kws={'s': 20, 'alpha': 0.3},
                 line_kws={'lw': 4});
plt.title('Escala Logaritmica')

sns.lmplot(x='tempo_emprego',
                  y='renda', 
                 data=df1_new, 
                 scatter_kws={'s': 20, 'alpha': 0.3},
                 line_kws={'lw': 4})
plt.title('Sem outliers')

sns.lmplot(x='tempo_emprego',
                  y='renda', 
                 data=df1, 
                 scatter_kws={'s': 20, 'alpha': 0.3},
                 line_kws={'lw': 4})
plt.title('Com outliers');

# %% [markdown]
# 5) A aplicação do LOG você acha que melhorou ou piorou a análise?

# %% [markdown]
# A utilização da escala logarítmica apresentou um gráfico mais limpo e organizado, dando a impressão de uma leitura mais fácil dos dados comparativos da renda x tempo de emprego.
# Porém, algumas desvantagens puderam também ser observadas neste modelo:
#    1) O logarítmo acaba substituindo os valores da renda por um índice, o que acaba prejudicando a análise;
#
#    2) A variação no índice de correlação da coluna y_log foi muito pequena para justificar a sua utilização do logarítimo.
#     Este efeito pode ter relação direta com o fato de que a renda e o tempo de emprego não constitui necessariamente um fator multiplicativo.![log-2.png](attachment:log-2.png)
